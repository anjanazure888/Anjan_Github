# %%
dbutils.fs.ls("abfss://demo@anjanltmstorage.dfs.core.windows.net")

# %%
dbutils.secrets.help()

# %%
dbutils.secrets.listScopes()

# %%
dbutils.secrets.list("scope-ltm")

# %%
dbutils.secrets.get('scope-ltm','secret-ltm')

# %%
dbutils.secrets.get("scope-ltm","secret-ltm")

# %%
spark.conf.set("fs.azure.account.key.anjanltmstorage.dfs.core.windows.net",dbutils.secrets.get("scope-ltm","secret-ltm"))

# %%
dbutils.fs.ls("abfss://demo@anjanltmstorage.dfs.core.windows.net")

# %%
dbutils.fs.ls("abfss://deletecontainer@anjanazure888dbstorage.dfs.core.windows.net")

# %%
dbutils.secrets.listScopes()

# %%
dbutils.secrets.list("scope-anjan")

# %%
dbutils.secrets.get("scope-anjan","secret-anjan")

# %%
spark.conf.set("fs.azure.account.auth.type.anjanazure888dbstorage.dfs.core.windows.net", "SAS")
spark.conf.set("fs.azure.sas.token.provider.type.anjanazure888dbstorage.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.sas.FixedSASTokenProvider")
spark.conf.set("fs.azure.sas.fixed.token.anjanazure888dbstorage.dfs.core.windows.net", dbutils.secrets.get("scope-anjan","secret-anjan"))

# %%
display(dbutils.fs.ls("abfss://deletecontainer@anjanazure888dbstorage.dfs.core.windows.net"))

# %%
display(dbutils.fs.ls("abfss://anjanazure888bronze@anjanazure888dbstorage.dfs.core.windows.net"))

# %%
dbutils.secrets.listScopes()

# %%
display(dbutils.fs.ls("abfss://demo@anjanltmstorage.dfs.core.windows.net"))

# %%
df_customers= spark.read.csv("abfss://demo@anjanltmstorage.dfs.core.windows.net/customers-100.csv")
df_customers.display()

# %%
display(dbutils.fs.ls("abfss://ltmsource@anjanltmstorage.dfs.core.windows.net"))

# %%
df_circuits=spark.read.csv("abfss://ltmsource@anjanltmstorage.dfs.core.windows.net/circuits.csv")
df_circuits.display()

# %%
display(dbutils.fs.ls("abfss://deletecontainer@anjanazure888dbstorage.dfs.core.windows.net"))

# %%
df_races=spark.read.csv("abfss://deletecontainer@anjanazure888dbstorage.dfs.core.windows.net/races.csv")
df_races.display()

# %%
display(dbutils.fs.ls("abfss://anjananjanazure888bronze@anjanazure888dbstorag.dfs.core.windows.net"))
