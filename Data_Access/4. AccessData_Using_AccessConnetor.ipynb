# %% [markdown]
# **ACCESS CONNECTOR**
#
# No need of Keys ,configuration
# Automatic Authenticated centrally by unity catalog

# %%
display(dbutils.fs.ls("abfss://demo@anjanltmstorage.dfs.core.windows.net"))

# %%
display(dbutils.fs.ls("abfss://ltmsource@anjanltmstorage.dfs.core.windows.net"))

# %% [markdown]
# Read Data from ADLS storage file

# %%
display(dbutils.fs.ls("abfss://demo@anjanltmstorage.dfs.core.windows.net"))

# %%
df_customers=spark.read.format("csv")\
    .option("header","true")\
        .option("inferSchema","true")\
            .load("abfss://demo@anjanltmstorage.dfs.core.windows.net/customers-100.csv")
display(df_customers)

# %%
display(dbutils.fs.ls("abfss://ltmsource@anjanltmstorage.dfs.core.windows.net"))

# %%
df_circuits = spark.read.csv("abfss://ltmsource@anjanltmstorage.dfs.core.windows.net/circuits.csv")
df_circuits.display()
